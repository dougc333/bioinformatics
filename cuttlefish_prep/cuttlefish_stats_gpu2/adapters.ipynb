# %% [markdown]
# <h6>Adapter QC wo programming</h6>
# <p>
# https://support.illumina.com/content/dam/illumina-marketing/documents/products/technotes/technote_nextera_matepair_data_processing.pdf
# </p>
# <p>
# gives a list of 5 adapter sequences in the nextera mate pair library prep.
# </p>
# <p>
# 1) which prep kit did we use and which adapter sequences are there? and which part of the sequence is PCR and adapter
# </p>

# %%
#write into file single_read.fastq.gz
output = gzip.open("home/dc/singleread.gz", 'wb')

with open("/home/dc/empty_S316_L008_R1_001.fastq.gz") as fh1, open("/home/dc/empty_S316_L008_R2_001.fastq.gz") as fh2:
    #parse DNA string out
    for x, y in izip(fh1, fh2):
        x = x.strip()
        y = y.strip()
        
        write("{0}\t{1}".format(x, y))

# %%
import sys,os
print(os.getcwd())
kmers_51=[]
with open("/Users/dc/Downloads/sepia_lycidas_mito.txt") as fh:
    data = fh.readlines()
    print(len(data))
    for x in range(0,len(data)-51+1):
        kmers_51.append(data[x:x+51])

for x in kmers_51:
    print(len(x))
print(len(kmers_51))
# Out:
# /Users/dc/bioinformatics/cuttlefish_prep/cuttlefish_data
# 233
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51

# %% [markdown]
# <h6>First Run BBMap, removes 3-4% with default settings</h6>
# <img src="donothing.png">
# <h6>add nextera adapters to adapters.fa, no change</h6>
# <img src="addnextera.png">

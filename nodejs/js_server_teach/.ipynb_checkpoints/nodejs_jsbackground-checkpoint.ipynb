# %% [markdown]
# <h6>Nodejs programming</h6>
# Why nodejs? Event driven scalable server least amount of work to get data from servers doing work into visualizations.
# Other technologies work also but nodejs is the fastest hence cheapest solution at scale for real time data processing and
# display
# <h6>Concepts</h6>
# have to be clear on prototypes, closures functoin scope for Objects
# prototype chains.

# %% [markdown]
# <h6></h6>
# JS is untyped unlike C. Function level scope vs. block level scope like C/Java.
# Function level scope implies some new concepts like hoisting and the scope of variables global vs. function scope.
# <img src="jsdefn1.png">
# <img src="jsdefn2.png">
# Example pass functions as variables:<br/>
# Example prototypical inheritance:<br/>
# 2 ways to declare a function<br/>
# 1) using the function keyword<br/>
# 2) function expression where a variable is assigned to a function<br/>
# var foo = function this_is_a_test_function(param1){//do something w param1}<br/>
# var is function scope. You can reassign foo.<br/>
# let and const are block scope. const is like the const keyword in C/C++. Once assigned it is immutable for
# primitive data types and assignments to variables.<br/>
# For an object const refers to keeping the reference location constant. The properties of the object
# can be changed. const a = {name:"a", age:100}. a.name="b" is ok.
# let can be updated.<br/>
# let a=10;<br/>
# function foo(){<br/>
#   let a=5;<br/>
# }<br/>
# The above a are 2 separate variables. One with global scope one with local function scope. <br/>
# Seems like var is dead; use let and const. <br/>
# <img src="const1.png">
# <img src="const2.png">
#
# <img src="func1.png">
# <img src="func2.png">
# In a function expression you can only use the name of the function inside the funtion. factorial only exists inside
# the function scope. It does not exist outside the function scope of factorial.
# <img src="func3.png">
# parameters same for function declarations and function expressions. A function expression allows an anonymous function
# which is a function without a name. There are other small points like JS allows more parameters than in the function
# declaration, etc.. we don't conver these in a class; only cover the most useful features required to get people boostrapped
# and they can learn the rest with more experience.
#
# hoisting which lits var decls to the top of the program.

# %%
<h6>Hoisting Intro</h6>
Source:https://scotch.io/tutorials/understanding-hoisting-in-javascript
This is a big mess. For ES5
The quiz section got some concepts wrong. function decls are hoisted. var decls are also hoisted. <br/>
Now bear in mind in ES6 we aren't supposed to be using var decls, we are supposed to substitute them
with const and let decls. <br/>
Consider getting the type of a new variable, something which has not been initialized or declared:<br/>
    typeof(neverdeclared)<br/>
    "undefined"<br/>
Because we ran the typeof function, the variable neverdeclared is now declared. If we type neverdeclared<br/>
into the console to get the value we get undefined:<br/>
    neverdeclared<br/>
    undefined<br/>
It returns an undefined value and is an undefined type. <br/>
If you try to access this memory location of a never before seen variable in the JS browswer runtime<br/>
you should see an undefined reference because the runtime has never seen this variable newvar:<br/>
    console.log(newvar)<br/>
VM349:1 Uncaught ReferenceError: newvar is not defined<br/>
    at <anonymous>:1:13<br/>
(anonymous) @ VM349:1<br/>
You get an error because the memory has never been allocated or created. In contrast using an undelared var in a function type() the<br/> 
memory has been declared and initialized to undefined. <br/>
If you use 'strict' mode then supposedly there is no hoisting! <br/>
CAREFUL: each runtime needs testing. All the browsers are different, historically IE6 behaving unpredictably 
    vs. the other W3c standards and mobile/nodejs server runtimes can also be different. There is no incentive
    to keep all the corner cases consistently the same. 
The other way to look at the above is if you type in a var which has never been seen by the JS interpreter, <br/>
you get an UncaughtReferenceError. Lets try the new var never<br/>
    never<br/>
VM511:1 Uncaught ReferenceError: never is not defined<br/>
    at <anonymous>:1:1<br/>
<p></p>
    
Now lets repeat the above experiment with an example where we log the new variable but we <br/>
declare and assign the variable later in the file. But it is in the same file. <br/>
    
    console(myNew) <br/>
    var myNew ="this is hoisted"<br/>

Running this code we get undefined! We should have gotten a ReferenceError:myNew is not defined. We got an undefined<br/>
    because the myNew declaration was hoisted! The statement var myNew="something" consists of 2 statements, <br/>
    a declaration
    followed by an assignment. The JS interpreter takes the decl and hoists it but not the assignment!<br/>
    That is insane. <br/>
    
<h6>Testing hoisting</h6>
We have so far tested inside block scope; the simplest case. We should really test what happens when a decl is 
inside a function scope; does it get hoised to global scope? That part really sucks cause you have no idea
what people are doing inside functions which are hidden from you in a big .min js file. 

<h6>Hoisting ES6</h6>

Again from: https://scotch.io/tutorials/understanding-hoisting-in-javascript
In ES6 we use const and let! Great idea. No sucky undeclared vars contaminating the global scope.

# %%
<h6>Template Literals</h6>
JS allows template variables as part of the language/runtime definition. Use backticks to indicate template
literal:<br/>
    `this ia a backick ${foo}`<br/>
where the variable foo is replaced in the template literal after evaluation
Template Literals: 
    https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Template_literals

# %%
<h6>JS Objects</h6>
An object is an associative array which is an array of key/value pairs. Most represent a JS object/KV pairs w/JSON. 
<img src="object1.png">
<img src="object2.png">
Use the new Object() to create an object reference w/no properties. You can add a property to an object by adding a property dynamically to the object instance:<br/>
    objName.prop = value<br/>
An object created via new() is a  user defiend object which inherits from the Object prototype. The JS
Object() ctor returns a reference to the created object.<br/> 
myobj = new Object();<br/>
You can create an object using new() or using the object literal syntax below. The OL syntax supposedly is faster
according to the blog posts because the OL syntax directly allocates memory whereas the new() ctor both allocates the
memory then writes it in 2 separate ops. Not sure if this is really true given the state of today's runtimes. The blog 
posts also say to use OL notation but this isn't as readable. 
<img src="object3.png">
<img src="object4.png">
<img src="object5.png">
<img src="object6.png">
Delete on an object property removes the property from the object
<img src="object7.png">
<img src="object8.png">
There are 2 equality operators in JS. Use ===. The old days we only had ==. == performs type conversion before
doing the equality test so you get corner cases like 0=='0' is true while false=='false' is false. Never use == or
!== anymore in JS. 
<img src="object9.png">
<img src="object10.png">
<img src="object11.png">
<img src="object12.png">
<img src="object13.png">
<img src="object14.png">
<img src="object15.png">
<img src="object16.png">
<img src="object17.png">
<img src="object18.png">
Redo the above OO slides with a couple examples showing objects, properties, and how they inherit from the global
prototype object; how you can override with JS objects/classes. 
OK this is obvious. 
<img src="o2.png">
<h6>JS Classes</h6>
Source: https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Classes
Classes can be defined via the class declaration. 
class Rectangle{
    constructor(height,width){
      this.height=height;    
      this.weight = weight;
    }
}

Function declarations are hoisted. Class declarations are not. Class definitions have to occur before
classes are instantiated. 
Classes can also be defined as class expressions. A class expression can be named or unnamed. 
var Rectangle = class{
    constuctor(height,width){
        this.height=height;
        this.width=width;
    }
}

var Rectangle = class Rectangle{
    constuctor(height,width){
        this.height=height;
        this.width=width;
    }
}

# %% [markdown]
# <h6>Objects2</h6>
# Too verbose. Rephrase this to create encapsulated objects and classes for a webserver. Most of the work is importing
# libraries which are already in classes/objects. We are doing to create our own library in python for jupyter notebook
# whcih the datascience ppl can use. This may not fit anywhere.
#
#
# <img src="object2a.png">
# REST parameter syntax is 3 dots before the argument. This specifies an array which is the rest of the arguments in
# the parameter list. Tricky.
# <img src="object2b.png">
# <img src="object2c.png">
# automatic semicolon insertion, have to put the return value on same line as return keyword.
# <img src="object2d.png">
# example for ASI bug. this means the function will return undefined.
# <img src="object2e.png">
# <img src="object2f.png">
# The problem with function scope vs block scope is shown here. If this were block scope this would be wrong because
# a global is being overwritten by local scope. In function scope the statement inside the function can access variables
# outside of the function. Kinda funky.. the other thing is an undeclared variable has global funciton scope. Not sure
# this slide is really helpful. This is a dangerous slide. Never ever have undeclared variables in JS. It will work
# but will always cause problems.
# <img src="object2g.png">
# This is important for loop variables. Make sure you declare them in the function scope.
# <img src="object2h.png">
# higher order functions are one of the most powerful tools in JS. A HOF is a function which takes in a function
# as a parameter or returns a function.
# <img src="object2i.png">
# note how you use 2 sets of parenthesis to call the 2 chained functions
# <img src="object2j.png">
# Closures are hwo an inner function can access the outer function parameter x.
# <img src="object2k.png">
# <img src="object2l.png">
# <img src="object2m.png">

# %% [markdown]
# <h6>Objects3</h6>
# <img src="object3a.png">
# <img src="object3b.png">
# <img src="object3c.png">
# <img src="object3d.png">
# <img src="object3e.png">
# <img src="object3f.png">
# <img src="object3g.png">
# <img src="object3h.png">
# <img src="object3i.png">
# <img src="object3j.png">

# %% [markdown]
# <h6>Objects4</h6>
# <img src="object4a.png">
# <img src="object4b.png">
# <img src="object4c.png">
# <img src="object4d.png">
# <img src="object4e.png">
# <img src="object4f.png">
# <img src="object4g.png">
# <img src="object4h.png">
# <img src="object4i.png">
# <img src="object4j.png">
#
# <img src="object4k.png">
# <h6>Bind example</h6>
# console.error.bind(console) and console.log.bind(console)
# <img src="object4l.png">
# <img src="object4m.png">
# <img src="object4n.png">
# <img src="object4o.png">

# %% [markdown]
# <img src="server1.png">
# <img src="server2.png">
# <img src="server3.png">
# <img src="server4.png">
# <img src="server5.png">
# <img src="server6.png">
# <img src="server7.png">
# <img src="server8.png">
# <img src="server9.png">
# <img src="server10.png">
# <img src="server11.png">
# <img src="server12.png">
# <img src="server13.png">
# <img src="server14.png">
# <img src="server15.png">
# <img src="server16.png">
# <img src="server17.png">
# <img src="server18.png">
# <img src="server19.png">
# <img src="server20.png">

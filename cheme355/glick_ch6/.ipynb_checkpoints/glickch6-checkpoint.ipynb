# %% [markdown]
# <h6>Crossover</h6>
# Crossover refers to DNA from different chromosomes crossing over and recombining. When the DNA strand from a chromsome
# crossovers the other strand there is splicing where DNA from each strand is spliced to the next one.
# <img src="c1.png">
# Double crossover, crosses over 2 times.
# <img src="c2.png">
# <img src="c3.png">

# %%
<h6>Glick Ch6 c6 195-205, 222-228</h6>
this is the best part of the class. very useful. 
<p>Vectors are DNA sequences which can be replicated via plasmids,viruses, cosmids, artificial plasmids. They control
transcription, translation, protein stability, and sectreion of hte product of the cloned gene from teh host cell.
Expression vectors are plasmids which turn on/off under user control. Expression vectors are designed to 
not express the cloned gene until you turn it on by 1) heat(pL system) 2) add IPTG(T7 system bc T7 uses lacUV5), 3) TAC system(add IPTG)
</p>
Plasmids in cells impose a metabolic load on host cell. After several cycles of replication
then the plasmid cells are less and less because the stronger cells wo plasmids will dominate.
Some host cells expel plasmids. The non plasmid infected cells will
grow faster so eventually the cell culture will be dominated by non plasmid containing cells. A different strategy
is to not use a continuously expressed gene, find a promotor in a bacteria which is not contiunously on
but only turns on in certain part of the lifecycle. These are called expression vectors. pET system is 
one of these. 
<h6>TAC promotor system</h6>
<p>The most common regulatable promotor is the E Coli are the lac and trp operons. The tac promoter is synthetically
created from those 2 promoters, -10 upstream of where the lac promoter starts transcriptio and 
-35 of the trp promoter. TAC promoter has higher transcription rates than either LAC or TRP!!!! 
<li>lac promoter: normally off, allows ecoli to use lactose vs. glucose. lac promoter turned off by lac
    repressor protein. Induciton of lac promoter by 1) addintg lactose or 2) IPTG. These prevent the 
    lac repressor protein from binding to the lac promotor. Latose has to be
    converted to allolactose first which requires ß-galactosidase. ß-galactosidase is created by lacZ gene
    of lac(3 genes, alpha,beta,z) operon. If you use lactose the concentrattions won't
    remain constant because it is decomposed as above. If you use IPTG the concentration remains
    constant and may lead to more accurate reproduction/experimental consistency. 
    Use lacUV5 vs. wild type lac. in plasmid expression vectors. </li>
<li>tac promoter:normally off, turn on by adding IPGT or lactose. Follows ruls for lac operon even though
    it consits of lac+trp. </li>
<li>trp promoter: turned off by trp repressor protein. Turn on by removing tryptophan or adding 3-indoylic acid. 
    Nobody uses this bc this promotor is leaky, alwsys some small amount of transcription. Cannot use w/proteins
    which are toxic to ecoli but bc it is leaky it also takes energy away from ecoli replication</li>
<h6>pL promotor system</h6>
<li>pL promoter from lambda bacteriophage: normally off until temp reaches 42 degrees C, let cells 
grow in tempo 29-30 degrees C then when they are grown, turn on pL by raising temp. </li>

<h6>Gene 10 T7 promotor system</h6>
<li>t7 promoter from T7 bacteriophage:normally off, turn on or induce by adding IPTG. The T7 promotor is controlled
    by tehe lacUV5 promotor which is turned on/off by IPTG or lactose. Dont use lactose bc it requires
    lactose to be converted to allolactose first. </li>
<p>tac and trc promotors 3x strong as trp and 10x as lac!!! T7 stronger than all of these. </p>
<h6>LAC operon</h6>
The LAC gene/operon needs 2 things to start rapid transcription
1) presence of lactose or IPTG to turn on the binding of the lac repressor protein to the promotor region
2) presence of CAP/cAMP 
<img src=t1.png>
From wikipedia, clearer
<img src=betterlac.png>

TAC and TRC promotors are very close to each other, different by only 1 base pair!!! TAC is synthetic!!!
Part A shows lactose being converted to allolactose. 
<img src=t2.png>
<h6>pL promoter system showing heat turns on gene expression</h6>
<img src=t3.png>
<h6>The famous T7 promoter system!!!</h6>
The lac promotor turns on the T7 operon/gene. There is a lac repressor protein preventing T7 transcription. Adding IPTG
prevents the lac repressor protein from binding to the lac promotor which allows T7 transcription by creating 
the T7 RNA polymerase which then turns on T7 by producing T7 transcription/polymerase. 
<img src=t4.png>
<img src=t5.png>
<img src=t6.png>
<img src=t7.png>
<p>
<h6>DNA Integration into Host Chromosome. </h6>
From the hw ecoli cells use half ATP for cell growth/replication/metabolism. 
Alternative is to integrate DNA into host cell. NUMBERS? How much better is this than plasmid taking up 50% ATP?
The problem is when plasmids in host cells take up cell energy then in equilibrium the cells which 
dont have the cost of plasmid processing dominate. 2 methods to fix. 1) add antibiotic resistance to plasmid
cells so the others non plasmid cells die out. 2) integrate DNA into host chromosome. 
Eukaryotes don't all have plasmids like prokaroytes. In the case where we can't use plasmids to produce
cloned product we have to integrate our genes into the gDNA or chromsomal DNA of the lucky host. The clone gene
has to be placed in a part of the host chromosome where it doesn't kill the host. The clone gene must also
be under control of a regulatable promoter. This process of integration is called homologous recombination. 
2 main requirements. More to follow: 
</p>
<li>1) for a DNA insert into CHROMOSOMAL site , first needs to be sequence overlap of 50 nt between the insert
and the chromosoal DNA. Identiy site</li>
<li>2) isolate and clone part or all of chromosomal site</li>
<li>3) ligate a cloned gene and regulatable promoter into 6.25a or adjacent to 6.25b </li>
<li>4) transfer the DNA to a host cell as part of a plasmid that cannot replicate in a host cell</li>
<li>5) seldct and perpetuate cell which express cloned gene. </li>
There are 2 different cases of how the gene is combined, bottom is hoologous combination. This figure 
is important in the context of CRispr. 
<img src=s1.png>
<img src=s2.png>
<img src=s3.png>
<img src=s4.png>
<img src=s5.png>
<img src=s6.png>
<img src=s7.png>
<img src=s8.png>
<img src=s9.png>
<img src=s10.png>
<img src=s11.png>
<img src=s12.png>
Homologous recombination diagram: how to remove a selectable marker w
    cre/lox. 
<img src=s13.png>
<img src=s14.png>

# %%
<h6>CRISPR CAS9</h6>
I dont understand the workflow. 
Plant example:https://ac.els-cdn.com/S0176161704704605/1-s2.0-S0176161704704605-main.pdf?_tid=9918969f-2b81-4016-a41c-6cd1511ec07d&acdnat=1526032801_09cb3548eb1ae61b52adac06d7a1c7f4
There are 2 pathways to crispr repair: nonhomologous end joining for gene knockout and homologous recombination. 
1) NHEJ: https://blog.addgene.org/crispr-101-non-homologous-end-joining
        Can add a stop codon or cause a frame shift mutation. Is a stop codon a NHEJ?

# %%
1.  Suggest several ways that the expression of a cloned gene can be manipulated for optimal expression. 
1) promotor design, which one to select, different strengths give different transcription rates. 
2) amount of suppressor protein or activating agent to neutralize suppression protein to control transcription rate
- reduce effect of supressor protein on promotor. Strenght of suppressor controlled by ratio of supressor proteins/copies of promotoer
sequences. increase number of promotor sequences and decrease number of suppressor proteins. This is shown in the 
chart showing level of transcription vs. glucose concentration/lactose concentration/cAMP concentration
3) codon optimization, matching the distribution of codons in the inserted gene to match the host organism
distribution. 
2.  What is lacIq , and how is it used? 
Mutated form of lacI gene which reduces leakage under non induced conditions. 
THis pprudces higher levels of lac repressor. 
3.  Why is the plasmid that contains the strongest promoter not always the best expression vector? 
Strong promoter reduces energy available for cell metabolism and uses other than inserted gene expression.
Higher probability/degree of toxicity to the cell. 
4.  What is the tac  promoter, and how is it regulated?
2 parts, first: lac repressor protein. turn off w/IPTG or adding lactose. 
second: transcription of lac promoter regulated by Catabolite activator protein. When CAP/cAMP binds to the CAP
    box it increases the
    promotor affinity for RNA polymerase increasing transcription rates. 
5.  The pL  promoter is derived from E. coli  bacteriophage λ , which cannot infect other bacteria, 
yet it is sometimes used as part of a broad-host-range expression vector. 
Explain how the pL  promoter can be used to promote transcription in organisms other than E. coli . 
6.  Sometimes the strategy for the expression of a target protein in a host organism involves synthesizing the protein as part of a fusion protein. Why is this approach useful? How is a fusion protein created? 7.  What are inclusion bodies, and how can their formation be avoided? 
8.  Why would you want to express a foreign protein on the surface of a bacterium or bacteriophage? How would you do this? 
9.  How would you manipulate the DNA sequences upstream of a target gene to modulate expression of that gene? 
add promotors, can chain them together like tac system. 
10.  How would you avoid some of the problems associated with the limited amount of oxygen 
that is available to growing E. coli  cells when a foreign protein is overproduced? 
11.  A specific target DNA fragment to be integrated into the chromosomal DNA of the host organism can include 
(1) only the target gene sequence or 
(2) the entire plasmid, including the target sequence. 
singke crossover vs double crossover? 
homologous recombination integrates the plasmid into the target. 
Explain how each of these results might occur. 

What are the advantages or disadvantages of the plasmid vector becoming incorporated into the host chromosomal DNA? 

1) Plasmids can be expelled by the host. 
2) advantage can use cre-lox syste
12.  What factors are responsible for a metabolic load? 
1) cellular metabolism
2) transcription
3) translation

13.  Suggest a number of different strategies to limit the extent of metabolic load on E. coli  
cells that are designed to overproduce a recombinant protein. 
1) wait until the cells are grown to OD=600 or certain density before turning on transcription for protein. 
    can use heat activated or IPTG activated promoters. 
2) do not express protein continuously throughout cell growth phases. 
14.  During the course of integrating a target gene into the chromosomal DNA of the host bacterium, a marker gene may also be inserted into the chromosomal DNA. 
What strategy could be used to excise only the marker gene? 
1)cre-lox system. 
15.  How do biofilms limit the production of recombinant proteins? How might this limitation be overcome? 
16.  How can E. coli  host cells be engineered so that complex proteins with a large number of 
disulfide bonds are properly folded and therefore produced in an active form 
rather than as part of an inclusion body?

17.  How can E. coli  host cells be engineered to yield high levels of expression of 
foreign proteins that contain significant numbers of rare E. coli  codons? 

18.  What is the T7 expression system, and how does it work? 

T7 is a bacteriophage and gene promoter used to create RNA from DNA placed downstream.  The T7 promoter 
is normally off, allowing the Ecoli culture to use all of the cell energy for replication. The T7 promotor is controlled
by an upstream lac promotor. The lac promotor is off unitl IPTG is placed in the medium. Once a set OD is reached, 
add IPTG to induce the T7 promoter to transcribe the cloned gene. Works at a faster speed 
than the native EColi RNA polymerase. 1h lag between time of induce till gene is transcribed. Part of Novatel pET. 
It is used for EColi gene expression and is used to translate the DNA in the 
plasmid into mRNA/RNA. 5′ TAATACGACTCACTATAG 3′ . The 
rna transcription starts from the lagging G and uses the opposite strand fom 3->5. CTATAGTGAGTCGTATTA. 
toxic implies let it grow to a certain cell density, kill/harvest. In the Basic Protocol, two plasmids are maintained within the same E. coli cell. 
One (the expression vector) contains p(T7) upstream of the gene to be expressed. 
The second contains the T7 RNA polymerase gene under the control of a heat-inducible E. coli promoter. 

19.  What features affect the strength of a bacterial promoter? 
1) absence of a regulator. If the regulator is present then the promotor is off. 
20.  How can a protein of interest be engineered to be secreted to the medium by E. coli? 
21.  What is an intein, and how is it used to purify foreign proteins expressed in E. coli?

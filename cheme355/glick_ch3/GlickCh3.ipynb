# %% [markdown]
# <h6>Glick Ch3</h6>

# %%
<h6>Produce DNA w/o cloning, Gibson Assembly</h6>
https://en.wikipedia.org/wiki/Gibson_assembly
    
How is gibson assembly different from PCR?

# %%
<h6>Transormation and Selection</h6>
The process of uptake of the designed plasmid into Ecoli is called transformation. A cell which is capable of
taking in this DNA is called competent. When cell density is high or starvation impending bacterial cells will produce
proteins which aid in uptake of plasmids. Transformation defined as 1) binding of double stranded DNA to cell wall, 
2) entroof DNA into inner compartment, periplasm, 3) transmission of 1 strand into the cytoplasm while the other
is degraded, 4) if hte DNA is linear integration into the host chromosome. Competence can be induced by CaCl2 and 
heat shock. If the introduced DNA is a plasmid, it is maintained in the cytoplasm until the second strand is 
synthesized. Transformation efficience defined as number of transformed cells as funciton of amount of DNA added.
Transformation efficiency is approx 10^7 tp 10^8 transformed cells per microgram of intact plasmid DNA. 
Transformation
inefficeint, about 1/1k cells are transformed. 
<li>Bacteria which are RecA- have higher prob of success</li>
<li>Bacteria that dont produce endonulcease encoded by endA1 gene have higher tranformation frequencies</li>
For selection, 2 antibiotic resistant genes are insterted into the plasmid so after putting in plate w/Antibiotics
the ones which took in the plasmid should survive. 
<img src="t1.png">

<img src="t2.png">
<img src="t3.png">
<img src="t4.png">

# %%
Other bacteria like Bacillus subtilis and Agrobacterium tumefaciens act as a final host cells. Cloning 
vectors that funciton in EColi can have a second ORI to enable the plasmid to replicate in a separate
host cell! Shuttle vectors are vectors which can operate in 2 different hosts. Prokaryotes dont have intons, Eukaryotes
do. There are some shuttle vectors which can operate in both. To create a shuttle vector, start with an Ecoli plasmid then 
combine the Ecoli plasmid part with the insert and antibiotic resistence gene with part of the host cell specific
plasmid with a origin of replication. This ORI is different than the Ecoli plasmid ORI. First step to make Shuttle
vector is to engineer 2 recognition sites for the restriction endonuclease SfiI. The seque3nce is GGCCNNNNNGGCC/CCGGNNNNNCCGG.
2 different sites SfiIx and SfiIy have 2 different sequences so after digestion with SFiI teh extesions of SfiIx 
are not complimentary to SfiIy. Then insert teh 2 SfiI sequences so after digestion they flank teh region containing
the antibiotic resistence gene adn cloing site on the EColi plasmid and the ORI on the host. The SfiIx-SfiIy procedure
can be adopted for any host cell that has a plasimid is called vector backbone exchange. 
<img src="g1.png">
Making a genomic library. Prokaryotes no intons. Eukaryotes have intons. Different genomic library prep procedures 
for both cell types. 
<img src="g2.png">
number of DNA fragments should be 3x size of DNA genome when cutting DNA for genomic library. Create a partial digestion
where you get a distribution of all possible cuts and fragment sizes. Assuming this is an even distribution. 
$$3\frac{gene length}{fragment size}=3\frac{4*10^6}{10^3)=12000$$ for genome 4*10^6 and fragnent size 1k. 
DNA library clone equation
$$N = \frac{ln(1-P)}{ln(1-f)}$$ Proof in the discussion slides
<img src="g3.png">
This is a partial digestion vs. a full digestion. The red arrows show the places where the DNA is cut
by the Restriction endonuclease, is you extend the time you get a wider distribution of smaller fragments. 
Can play with temp also in addition to heat. Reducing heat decreases effectiveness of RE. 
<img src="g4.png">
Table for genomic size. 
<img src="g5.png">
Once you have the DNA inserted in the clones; and they are replicated. How to filter out the ones you 
need? Denature DNA w/heat and RAPIDLY cool the single strands stay single. If the temp is lowered quickly
the single strands will start to base pair. Heating and SLOWLY cooling called annealing. When DNA from different
sources are annealed different source DNA will mix causing hybrids. We use this method to attach probe DNA to the sample
    target DNA. We label the probe DNA with either flourscent or radio tag markers. Hybrid assay bc/combining from different
                                                    soures, probe DNA+clone DNA
                                                    
<img src="g6.png">
Another method is the random primer method where you make all possible combinations of a 6 N sequence. Some of those will
    hybridize to teh target dna. UNCLEAR HOW THIS WORKS>..
<img src="g6a.png">              
                                                    
<img src="g7.png">
<img src="g8.png">
<img src="g9.png">
<img src="g10.png">
<img src="g11.png">
<img src="g12.png">
<img src="g13.png">
<img src="g14.png">
<img src="g15.png">
<img src="g16.png">
<img src="g17.png">
<img src="g18.png">
<img src="g19.png">
<img src="g20.png">
Electroporation: to increase uptake of DNA/plasmid; subject bacteria to high voltage electric field. DNA is negatively
charged, ecoli cells at 50 uliters are placed in chamger and pulse 20mF, 2.5kV and 200ohms for 4.6ms. This yields 10^9
                                                transformants/ug of DNA for small plasmids ~3kb and 10^6 for large plasmids(~136kb)
<img src="g21.png">
<img src="g22.png">

# %% [markdown]
# <img src="p1.png">
# <img src="p2.png">
# <img src="p3.png">
# <img src="p4.png">
# <img src="p5.png">
# <img src="p6.png">
# <img src="p7.png">
# <img src="p8.png">
# <img src="p9.png">
# <img src="p10.png">
# <img src="p11.png">
# <img src="p12.png">
# <img src="p13.png">
# <img src="p14.png">

# %%
. What are type II restriction endonucleases? 
Why are they important for recombinant DNA technology? 
2.  When circular double-stranded DNA from the plasmid pCEL1 is digested by various restriction endonucleases 
and combinations thereof, the following bands (with lengths given in kilobase pairs) are observed: 
    EcoRI, 6.0; BamHI, 6.0; HindIII, 6.0; HaeII, 3.0, 2.0, and 1.0; EcoRI and HaeII, 2.0 and 1.0; EcoRI and 
    HindIII, 3.5 and 2.5; EcoRI and BamHI, 4.5 and 1.5; BamHI and HindIII, 5.0 and 1.0; BamHI and 
    HaeII, 3.0, 1.5, 1.0, and 0.5; and HindIII and HaeII, 3.0, 1.5, 1.0, and 0.5. 
    Construct a restriction endonuclease enzyme site map with this information. 
3.  Describe how plasmid pBR322 is used as a cloning vector. What are its special features? 
4.  Describe the principal features of the pUC cloning system. 
5. A genomic library of a prokaryotic organism is often constructed by cloning the products of a 
Sau3AI partial digest of the genomic DNA into a BamHI site of the vector. 
a.  Why are two different enzymes used in this experiment? 
b. What is a partial digestion, and how is it performed? 
c.  Why is partial digestion often used for constructing genomic libraries? 
6.  For gene-cloning experiments, why is the cleaved plasmid DNA often treated with alkaline phosphatase 
prior to the ligation step? 7.  Suggest a few different ways that recombinant plasmids can be introduced into 
a gram-negative bacterium, such as E. coli . 
8.  Outline some of the strategies that are used to detect 
a cloned target gene within a library in E. coli . 
What conditions must be satisfied for each type of assay? 
9. What is a cDNA library? 
10.  Why would you use a plasmid, bacteriophage λ , cosmid, or 
BAC as a cloning vector? 
11. What is a common mode of action of a type IIS restriction endonuclease? 
12. What is replica plating? Outline the basic methodology for replica plating. 
13. What is a fosmid? 
14. What is a tripartite mating? 
15. What is the role of RNase H during cDNA synthesis?

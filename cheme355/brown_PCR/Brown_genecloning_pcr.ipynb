# %% [markdown]
# <h6>Cloning and PCR Brown Chapter1 and Chapter2 Note: download files are subset of original</h6>
# Gene cloning where a piece of DNA is inserted into the vector called a recombinant DNA molecule. This vector +
# DNA is a recombinant DNA molecule before insrtion intothe bacterium. Teh recombinant DNA dividies within the
# bacterium and the bacterium divides also. There are 2 places of replicaiton, inside the bacterium and the
# division of the bacterium. The copy number in the origin of replication determines how many copies of the plasmid
# there are in each cell. This number stays consstent across division. ie. 60/cell.
# <img src="b1.png">
# Steps to PCR
# <li>Denature double strand to create 2 single strands 94 degrees C. This breaks the H bonds in the double strand</li>
# <li>Anneal primers to end of DNA temlate by cooling 50-60. Primers at the end of the single strands prevent
# the single strnds from attaching back together. Primers are where the DNA polymerase starts replication for the single
# strands to do the read. Adapter sequences can be added for multiplixing. </li>
# <li>SYnthesize w/additon of DNA polymerase by heating back to 74 C</li>
# <li>synthesize from 3 to 5</li>
# <li>Heat back up to 94C to denature again ane repeat process</li>
# <img src="b2.png">
# <h6>Both methods, cloning and PCR allows us to select a particular gene from a pool of many DNA strands which
# have been replicated either in a host cell or in a test tube via PCR reactions. Advantage: PCR is faster then gene
# cloning. Disadvantages: PCR requires primers to anneal to correct positions, on both sides of gene. In class was
#     mentioned we can get a cut in the middle of a gene. PCR doesnt work for denovo genes, where we dont know
#     the sequence. For gene isolation in PCR we need to anneal primers to both ends of the gene sequence. For denovo
#     genes we need cloning. PCR has limit oto 40kb. Longer genes require cloning</h6>
# <h6>Plasmid selection intro</h6>
# insert DNA into vector RP4,some cells take in DNA some dont. Use antibiotic in growth media on right to kill off
# ones wo antibiotic.
# <img src="b3.png">
# Did not know this, there are 2 types of plasmids, one which replicate in the cell and ones where the plasmid
# becomes integrated into the ecoli DNA called episome.
# <img src="b4.png">
# There is a limit to size of plasmids, up to 250kb.
# <img src="b5.png">
# ecoli can have multiple plasmids from different bacteria/sources inside the cell.
# Not all are compatible. Have to do a check.  There is a classification
# scheme for plasmids.
# There are 5 types of plasmids
# <li>F plasmids contain tra genes and promote conjugal plasma transfer. There is a ecoli F plasmid. </li>
# <li>R pasmids have genes giving resistance to antibacterial agents like ampicillin. RP4 example. </li>
# <li>Col plasmids: ColE1 of Ecoli which create proteins which kill other bacteria</li>
# <li>Degradative plasmids: allow synthesis of unusual molecules like salicylic acid</li>
# <li>Virulence plasmids, Ti plasmid which induce gall disease on dicotyledonous plants</li>
# The best characterized plasmid is Saccharomyces Cerevisia. Other eukaroytes havent found plasmids. Yeast is as
# high as it goes for now.
#
# <img src="b6.png">
# Bacteria Phages are viruses which specifically target bacteria, we can use those to insert DNA into a bacteria.
# <img src="b7.png">
# 3 step process for phage to infect bacteria 1) enter into bacteria and inject DNA into bacteria, 2) phage enzymes replicate
# the phage DNA inside the bacteria, 3) genes in phage create new phage particles in bacteria! Very fast infection. Called
# lytic cucle.
# <img src="b8.png">
# Lysogenic phages, Lambga and M13 vectors. The lifecycis is different than the lytic cycle phages where there are
# bacteria divisions where the plasmid DNA is incorporated into the cellular DNA! the lambda DNA when linearized have
# sticky ends which allow them to bind to form cicrular DNA
# <img src="b9.png">
# <h6>Did not cover lambda and M13 phages and lifecycle/has real world applicaitons</h6>
# <img src="b10.png">
# <img src="b11.png">
# <img src="b12.png">

# %%
<h6>Brown Chapter 4</h6>
<img src="b13.png">
<img src="b14.png">
<img src="b15.png">
<img src="b16.png">
<img src="b17.png">
<img src="b18.png">
<img src="b19.png">
<img src="b20.png">
<img src="b21.png">
<img src="b22.png">
<img src="b23.png">

# %%
<h6>Brown Chapter 4</h6>
To get plasmid DNA into bacteria, 50mM CaCl and heat shock to 42C. Selection is not efficient. 1ng of pUC8 can yield
1000-10k transformations. THis is only .01% uptake of plasmids. 
<img src="ch5_1.png">
Selection with pBR322 where pBR322 contains genes to allow ecoli to modify antibiotic ampicillin and tetracycline. 
so not toxic to bacterium. 
<img src="ch5_2.png">
<img src="ch5_3.png">
<img src="ch5_4.png">
<img src="ch5_5.png">
<img src="ch5_6.png">
<img src="ch5_7.png">
<img src="ch5_8.png">
<img src="ch5_9.png">
<img src="ch5_10.png">
<img src="ch5_11.png">
<img src="ch5_12.png">
<img src="ch5_13.png">
<img src="ch5_14.png">
<img src="ch5_15.png">
